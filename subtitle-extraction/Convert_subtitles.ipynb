# %%
import srt

# %%
with open('data/365-Days_2020_English-ELSUBTITLE.COM-ST_55742757.srt') as f:
    subtitle_generator = srt.parse(f.read())

# %%
subtitles = list(subtitle_generator)

# %%
output_subtitles = []

for s in subtitles:
    output_subtitles.append([s.start.total_seconds(), s.end.total_seconds(), s.content])

# %%
import json

json.dump(output_subtitles, open('data/output/365_days.json', 'w'))
# Out:
# [[36.541, 41.375, '<i>THE ISLAND OF LAMPEDUSA\nMEDITERRANEAN SEA</i>'],
#  [63.791, 65.291, '<i>In the first batch,</i>'],
#  [65.75, 67.458, "<i>we've got 20 refugees.</i>"],
#  [69.0, 70.166, '<i>All young girls.</i>'],
#  [70.916, 72.875, '<i>Feel free to keep one.</i>'],
#  [75.333, 77.333, "<i>I'm afraid you've got the wrong address.</i>"],
#  [77.75, 80.666, '<i>But the merchandise is excellent.\nA real bargain.</i>'],
#  [81.75, 83.916, '<i>Some of them are barely 12.</i>'],
#  [85.083, 86.541, "<i>It's a lot of money.</i>"],
#  [87.625, 89.958, '<i>All you need to do\nis to help us get them here.</i>'],
#  [92.5,
#   95.125,
#   '<i>My family has never been\ninto this sort of business.</i>'],
#  [96.041, 97.5, "<i>I don't have to do anything.</i>"],
#  [98.958, 100.666, "<i>You're only wasting my time.</i>"],
#  [101.458, 104.125, "<i>I'm sorry. I didn't mean to offend you.</i>"],
#  [104.916, 106.0, '<i>Think it over.</i>'],
#  [107.166, 108.833, "<i>You'll get a good cut.</i>"],
#  [111.916, 112.75, '<i>Mario.</i>'],
#  [132.666, 133.75, '<i>Fucking assholes.</i>'],
#  [136.791, 138.958, "<i>However,\nhe's a potential business partner.</i>"],
#  [139.041, 140.375, '<i>He deserves our respect.</i>'],
#  [140.833, 142.375, '<i>Even if he is an asshole.</i>'],
#  [144.125, 145.541, '<i>What were you looking at?</i>'],
#  [150.25, 152.958, '<i>Oh, my son. You have to be careful.</i>'],
#  [154.041, 156.208, '<i>Beautiful women are heaven for the eyes</i>'],
#  [156.291,
#   158.791,
#   '<i>- and hell for the soul.\n- And purgatory for the wallet.</i>'],
#  [162.666, 163.625, '<i>Listen to me.</i>'],
#  [165.208,
#   169.083,
#   "<i>It's time for you to stop thinking about\nfun and pleasure.</i>"],
#  [169.416,
#   172.458,
#   '<i>You have to take on\nyour responsibilities, okay?</i>'],
#  [174.083, 178.625, '<i>One day, all of this... will be yours.</i>'],
#  [241.208, 243.5, "<i>♪ You keep telling me I'm free to go\xa0♪</i>"],
#  [243.875, 246.125, "<i>♪ But I'm addicted to you\xa0♪</i>"],
#  [247.125, 249.666, "<i>♪ It's a lie, it's a lie, it's a lie\xa0♪</i>"],
#  [252.791, 255.291, "<i>♪ When I'm not here, you're alone\xa0♪</i>"],
#  [255.75, 257.75, '<i>♪ And you walk by your own\xa0♪</i>'],
#  [258.791, 261.666, "<i>♪ Don't you lie, won't you lie\nDon't you lie ♪</i>"],
#  [261.75, 264.208, '<i>♪ And I think you should know\xa0♪</i>'],
#  [264.666, 267.166, "<i>♪</i> That I won't let it go\xa0♪</i>"],
#  [267.541, 269.458, '<i>♪ It was like a million times\xa0♪</i>'],
#  [269.541, 270.708, '<i>365 DAYS</i>'],
#  [270.791, 272.875, "<i>♪ I'm singing a lullaby ♪</i>"],
#  [273.25, 275.958, '<i>♪ And I think you should know\xa0♪</i>'],
#  [276.291, 278.916, "<i>♪ That I won't let it go\xa0♪</i>"],
#  [279.25, 280.916, '<i>♪ I thought that it was enough\xa0♪</i>'],
#  [281.0, 282.333, '<i>5 YEARS LATER</i>'],
#  [282.416, 284.833, "<i>♪ But I don't want to say goodbye... ♪</i>"],
#  [285.458,
#   288.666,
#   'We are terribly sorry,</i>\nbut it was possible to regain</i>'],
#  [288.75, 291.25, "<i>only 12 percent of your family's assets.</i>"],
#  [291.833,
#   296.125,
#   '<i>In the future, we recommend\na more heterogeneous investment portfolio.</i>'],
#  [296.458, 297.583, '<i>You </i>recommend?</i>'],
#  [299.041,
#   301.916,
#   '<i>This investment\nwas also highly recommended by you.</i>'],
#  [302.75, 304.541, '<i>- Good evening.\n- Good evening.</i>'],
#  [304.625, 305.708, '<i>WARSAW</i>'],
#  [305.791, 307.541, '<i>Have you packed your shit already?</i>'],
#  [309.041,
#   313.208,
#   '<i>Please, could anyone tell me\nwhat the hell happened here yesterday?</i>'],
#  [313.625, 314.791, '<i>I expect a refund</i>'],
#  [316.0, 317.375, '<i>and five percent interest.</i>'],
#  [317.791, 318.666, "<i>It's impossible.</i>"],
#  [318.75, 320.833, '<i>- Refund, and ten percent interest.</i>'],
#  [322.583, 324.0, '<i>Until the end of the month.</i>'],
#  [325.166, 327.041, '<i>My question is:</i>'],
#  [327.125, 329.208, '<i>How the fuck...</i>'],
#  [330.916, 331.833, '<i>did it happen?</i>'],
#  [331.916, 332.75, '<i>Hmm?</i>'],
#  [333.333, 334.666, '<i>You should ask Ms. Biel.</i>'],
#  [334.75, 335.875, '<i>Excuse my language,</i>'],
#  [335.958, 338.458, '<i>but you need to have balls to do this job.</i>'],
#  [338.791, 341.375, '<i>This conversation is over.</i>'],
#  [346.083, 348.166, '<i>- This is America.</i>'],
#  [352.291, 353.166, '<i>Ms. Biel?</i>'],
#  [354.0,
#   356.416,
#   "<i>- First of all, it's not my fault.\n- Listen, ma'am...</i>"],
#  [356.5, 358.375, "<i>I haven't finished yet.</i>"],
#  [358.958, 361.416, "<i>And it's not my job\nto temper rowdy customers.</i>"],
#  [361.5, 364.291, '<i>And I think you should rather tell us</i>'],
#  [364.375, 366.75, '<i>why, in the entire building,</i>'],
#  [366.833, 369.666, '<i>there were only two security guards.</i>'],
#  [371.0,
#   375.958,
#   "<i>Word... It is all about word\nthat you've given to my family.</i>"],
#  [380.541, 381.5, '<i>What is it?</i>'],
#  [382.041, 384.25, '<i>You have this game in America, right?</i>'],
#  [384.916, 385.75, '<i>Trick or treat.</i>'],
#  [386.083, 390.375, '<i>I checked in the band\nat our hotel on purpose.</i>'],
#  [391.041,
#   395.0,
#   "<i>And because of yesterday's incident,\nwe are in media from the US to Japan.</i>"],
#  [398.541,
#   401.666,
#   '<i>I thought that when it comes\nto sexual preferences,</i>'],
#  [402.125, 403.541, '<i>nothing would surprise me,</i>'],
#  [406.041, 407.0, '<i>but you...</i>'],
#  [408.708, 410.791, '<i>What would your loving husband say\nabout that?</i>'],
#  [412.041, 413.791, '<i>Your kids? Shareholders?</i>'],
#  [416.333, 417.25, '<i>Shall I continue?</i>'],
#  [419.25,
#   421.916,
#   "<i>You've embarrassed us\nin the eyes of entire world.</i>"],
#  [422.458,
#   425.458,
#   '<i>We all know how the media\nand the stock market will react</i>'],
#  [425.541, 427.083, '<i>when I make it all public.</i>'],
#  [427.75, 429.875, '<i>There have been so many reservations</i>'],
#  [429.958,
#   432.625,
#   '<i>that we are overbooked\nfor the next four weekends.</i>'],
#  [433.458, 434.833, '<i>After a week...</i>'],
#  [436.083, 437.708, '<i>bank shares will fall by half.</i>'],
#  [438.166, 440.208, '<i>It was possible because of my strategy.</i>'],
#  [440.291, 442.375, '<i>Age and sex had nothing to do with it.</i>'],
#  [442.458, 444.958, '<i>After a month, I will buy it for peanuts,</i>'],
#  [445.041, 445.916, '<i>only to...</i>'],
#  [446.375, 448.375, '<i>This is exactly\nwhat you need balls for.</i>'],
#  [448.458, 449.791, '<i>...fire you all.</i>'],
#  [451.5, 453.875, '<i>In my office. Right away.</i>'],
#  [456.75, 458.458, '<i>What are you gonna do about my money?</i>'],
#  [462.666, 465.166, '<i>♪ Every time you wanna walk out the door\xa0♪</i>'],
#  [465.833, 467.5, "<i>♪ I don't blame you\xa0♪</i>"],
#  [468.75, 471.416, "<i>♪ I don't blame you\xa0♪</i>"],
#  [471.5, 474.0, '<i>♪ And I think you should know\xa0♪</i>'],
#  [474.625, 477.041, "<i>♪ That I won't let it go\xa0♪</i>"],
#  [477.333, 479.833, '<i>♪ It was like a million times\xa0♪</i>'],
#  [480.291, 482.5, "<i>♪ I'm singing a lullaby\xa0♪</i>"],
#  [483.125, 485.708, '<i>♪ And I think you should know\xa0♪</i>'],
#  [486.041, 488.625, "<i>♪ That I won't let you go\xa0♪</i>"],
#  [489.0, 491.5, '<i>♪ I thought that it was enough\xa0♪</i>'],
#  [491.875, 494.583, "<i>♪ But I don't want to say goodbye\xa0♪</i>"],
#  [494.666, 499.166, '<i>♪ And I think you should know\xa0♪</i>'],
#  [506.458, 510.791, '<i>♪ And I think you should know\xa0♪</i>'],
#  [520.458, 522.916, "<i>-</i> - ♪ And it's hard for me\xa0♪</i>"],
#  [523.0, 525.583, '<i>♪ Hard for me, hard for me\xa0♪</i>'],
#  [526.958, 529.875, "<i>♪ And it's hard for me, hard for me ♪</i>"],
#  [530.291, 531.708, '<i>♪ Hard for me\xa0♪</i>'],
#  [532.791, 534.541, "<i>♪ Yeah, it's hard for me ♪</i>"],
#  [539.958, 541.083, '<i>Hi, honey.</i>'],
#  [543.208, 544.875, '<i>Damn, I have to finish this.</i>'],
#  [547.333, 549.25, '<i>Give me like half an hour, okay?</i>'],
#  [549.916, 551.916, "<i>Can't you just take a small break?</i>"],
#  [553.333, 554.541, '<i>Yeah, sure.</i>'],
#  [557.041, 558.541, '<i>You must be tired.</i>'],
#  [560.625, 562.458, '<i>We have a plane to catch in the morning.</i>'],
#  [564.625,
#   567.291,
#   "<i>You shouldn't strain yourself\nwith that weak heart of yours.</i>"],
#  [571.208, 572.041, '<i>Hmm?</i>'],
#  [587.416,
#   590.833,
#   "<i>Besides, you probably haven't packed\nfor us yet, right?</i>"],
#  [603.291, 604.791, "<i>I'm going to kill them.</i>"],
#  [625.083, 626.375, "<i>What's the matter?</i>"],
#  [628.5,
#   633.375,
#   '<i>Somebody has taken our container\nwith the cocaine.</i>'],
#  [668.708, 671.333, '<i>♪ Rings and rosies\xa0♪</i>'],
#  [672.041, 676.291, "<i>♪ Everybody's falling down\xa0♪</i>"],
#  [681.666, 684.833, "<i>♪ I've got your posies\xa0♪</i>"],
#  [684.916, 689.041, '<i>♪ Stuff your pockets, turn around\xa0♪</i>'],
#  [693.916, 696.916, '<i>♪ Ashes, ashes\xa0♪</i>'],
#  [697.0, 704.0, '<i>♪ We all go home ♪</i>'],
#  [706.125, 709.875, '<i>♪ I am the fire burning\xa0♪</i>'],
#  [710.5, 712.375, '<i>♪ I rise with the flames\xa0♪</i>'],
#  [712.458, 716.291, '<i>♪ I am the fire burning\xa0♪</i>'],
#  [717.0, 718.958, '<i>♪ I rise with the flames\xa0♪</i>'],
#  [719.041, 721.875, '<i>♪ I am the fire ♪</i>'],
#  [729.666, 733.416, '<i>♪ Take me to the fire burning ♪</i>'],
#  [734.5, 736.083, '<i>♪ I rise with the flames\xa0♪</i>'],
#  [736.166, 739.958, '<i>♪ I am the fire burning\xa0♪</i>'],
#  [740.875, 742.625, '<i>♪ I rise with the flames\xa0♪</i>'],
#  [742.708, 746.583, '<i>♪ Take me to the fire burning ♪</i>'],
#  [747.375, 749.166, '<i>♪ I rise with the flames\xa0♪</i>'],
#  [749.25, 752.958, '<i>♪ I am the fire burning\xa0♪</i>'],
#  [753.875, 755.625, '<i>♪ I rise with the flames\xa0♪</i>'],
#  [755.708, 759.458, '<i>♪ I am the fire ♪</i>'],
#  [768.625, 770.416, '<i>♪ I am the fire ♪</i>'],
#  [775.125, 776.708, '<i>♪ I am the fire ♪</i>'],
#  [776.791, 779.5, '<i>♪ I am the fire, I am the fire ♪</i>'],
#  [779.916, 784.958, '<i>♪ I am the fire, I am the fire ♪</i>'],
#  [797.041, 799.041, '<i>♪ Ashes, ashes\xa0♪</i>'],
#  [800.041, 804.916, '<i>- ♪ Ashes, ashes ♪\n- ♪ We all go home ♪</i>'],
#  [805.0, 809.958, '<i>- ♪ We all go home ♪\n- ♪ Ashes, ashes\xa0♪</i>'],
#  [810.041, 814.625, '<i>- ♪ Ashes, ashes ♪\n- ♪ We all go home ♪</i>'],
#  [842.041,
#   845.541,
#   "<i>Let's drink to the health\nof the sexiest, the best,</i>"],
#  [845.625, 848.041, '<i>and most wonderful woman in the world...</i>'],
#  [848.958, 850.125, '<i>my mother.</i>'],
#  [852.041,
#   855.625,
#   "<i>I was just kidding! I'm sorry.\nI meant my lovely Laura,</i>"],
#  [855.708, 860.666, '<i>who will, in a second, turn... 29.</i>'],
#  [860.75, 862.375, '<i>Come on, you make me feel old.</i>'],
#  [862.458, 863.833, '<i>Old, but still kicking.</i>'],
#  [864.375, 867.166, '<i>One moment.</i>'],
#  [877.416, 880.125, '<i>Today is the birthday...</i>'],
#  [881.541, 884.125, '<i>of my beautiful girlfriend, Laura.</i>'],
#  [884.916, 885.833, '<i>Ah...</i>'],
#  [885.916, 889.041, '<i>Please, give me a hand.</i>'],
#  [890.0, 891.291, '<i>What are you up to?</i>'],
#  [892.541, 893.416, '<i>Yes?</i>'],
#  [895.708, 899.958, '<i>♪ </i>Happy birthday to you ♪</i>'],
#  [900.041, 900.875, '<i>Whoo!</i>'],
#  [900.958, 904.791, '<i>♪ </i>Happy birthday to you ♪</i>'],
#  [904.875, 906.0, '<i>Yes, thank you.</i>'],
#  [906.083, 910.25, '<i>♪ </i>Happy birthday, Laura ♪</i>'],
#  [910.75, 915.291, '<i>♪ </i>Happy birthday to you ♪</i>'],
#  [915.375, 919.0, '<i>- Bravo!</i>'],
#  [923.125, 924.041, '<i>Cheers.</i>'],
#  [924.458, 925.958, '<i>Jesus, Martin, you are such a dumbass.</i>'],
#  [935.458, 937.458, '<i>- My favorite. You remembered.\n- Aww.</i>'],
#  [937.541, 938.791, '<i>- But...\n- What?</i>'],
#  [938.875, 940.791, "<i>To be honest... I didn't order it.</i>"],
#  [941.25, 943.0, "<i>Maybe it's on the house?</i>"],
#  [943.833, 946.166, '<i>All right,\nso we probably should drink to...</i>'],
#  [946.25, 949.0, '<i>No. Wait, I have to go to the bathroom.</i>'],
#  [950.208, 953.958, "<i>Can't fight Maslow's pyramid.\xa0</i>"],
#  [971.041, 972.583, '<i>Are you lost, baby girl?</i>'],
#  [995.083, 996.791, '<i>- It was just like him.\n- Yeah.</i>'],
#  [1001.333,
#   1004.208,
#   "<i>Look! Our wine is here.\nThat's what I'm talking about.</i>"],
#  [1005.708, 1007.0, '<i>Grazie.</i>'],
#  [1008.041, 1009.708, '<i>Okay, thank you.</i>'],
#  [1015.541,
#   1018.166,
#   '<i>God, why do these seagulls\nhave to be so loud?</i>'],
#  [1020.0, 1021.541, '<i>Where is Michał- angelo?</i>'],
#  [1023.5,
#   1026.458,
#   '<i>As you can see,\nthe child is playing in the wading pool.</i>'],
#  [1027.75, 1028.958, '<i>What about Martin?</i>'],
#  [1029.583, 1031.708, "<i>I don't know.\nHe wasn't there when I woke up.</i>"],
#  [1031.791,
#   1034.041,
#   "<i>I don't know where he is.\nHe doesn't answer his phone.</i>"],
#  [1034.333, 1036.125, "<i>What? But it's your birthday.</i>"],
#  [1036.416, 1037.625, "<i>You don't say.</i>"],
#  [1037.833, 1039.791, '<i>The next one is just a year away.</i>'],
#  [1041.375,
#   1043.541,
#   "<i>You know what?\nI'm not the most important thing to him.</i>"],
#  [1043.833,
#   1047.166,
#   "<i>In Martin's hierarchy,\nI'm way behind his buddies and his work.</i>"],
#  [1047.458, 1049.333, '<i>And most importantly, way behind him.</i>'],
#  [1051.541, 1052.458, '<i>Hi, honey.</i>'],
#  [1054.375, 1055.833, '<i>How are you? How about lunch?</i>'],
#  [1057.75, 1060.375, '<i>Lunch? Sure. Where were you?</i>'],
#  [1060.708,
#   1065.333,
#   "<i>Etna. You were sleeping like a log.\nDidn't want to wake you. Time's a-wasting.</i>"],
#  [1066.0, 1068.125, "<i>Yeah, time's a-wasting. Did you have fun?</i>"],
#  [1068.5, 1070.875, '<i>Jesus. It was fucking awesome.</i>'],
#  [1070.958, 1071.958, '<i>You would have liked it.</i>'],
#  [1072.041,
#   1074.458,
#   '<i>You can experience the sea and snow\nat the same time. Cool!</i>'],
#  [1075.083,
#   1077.708,
#   "<i>Idiot! Don't you remember?\nWe were supposed to go there together!</i>"],
#  [1077.791,
#   1080.041,
#   '<i>Why have you left me all alone\non my birthday?</i>'],
#  [1080.125, 1081.75, "<i>Jesus. Don't get so worked up.</i>"],
#  [1081.833, 1083.625, "<i>With your weak heart,\nyou shouldn't do that.</i>"],
#  [1083.708, 1085.625, '<i>Fuck off with that heart argument again.</i>'],
#  [1085.708, 1088.0, '<i>Do you care about\nanything other than yourself?</i>'],
#  [1088.083,
#   1090.958,
#   "<i>- What am I to you?\n- You think I don't care about you?</i>"],
#  [1091.375, 1093.041, "<i>I've been looking for this\nfor over an hour.</i>"],
#  [1094.041, 1094.875, '<i>Huh?</i>'],
#  [1095.708, 1096.666, "<i>See? It's for you.</i>"],
#  [1096.75, 1097.625, '<i>Hmm?</i>'],
#  [1100.0, 1101.75, '<i>Mmm. Thank you very much.</i>'],
#  [1102.291, 1103.541, '<i>- Now, fuck off!</i>'],
#  [1112.083, 1115.083, '<i>♪ They come with bows and arrows\xa0♪</i>'],
#  [1115.166, 1117.958, '<i>♪ They come with their swords drawn\xa0♪</i>'],
#  [1118.041, 1120.833, '<i>♪ They come with pistols at their sides\xa0♪</i>'],
#  [1120.916, 1123.5, '<i>♪ And torches lit with fire\xa0♪</i>'],
#  [1123.583, 1126.333, "<i>♪ They're stormin' every castle\xa0♪</i>"],
#  [1126.416, 1129.208, '<i>♪ Hoping to steal our gold\xa0♪</i>'],
#  [1129.291,
#   1134.625,
#   '<i>♪ Envious of the way\nWe have what they can never hold ♪</i>'],
#  [1136.166, 1138.166, '<i>♪ We are the hunted\xa0♪</i>'],
#  [1138.916, 1141.75, '<i>♪ We are the chosen ones ♪</i>'],
#  [1141.833, 1143.625, '<i>♪ We are the wanted\xa0♪</i>'],
#  [1143.708, 1146.0, "<i>♪ We are what they can't touch ♪</i>"],
#  [1158.416, 1159.583, '<i>Good evening.</i>'],
#  [1273.666, 1274.833, '<i>Fuck me.</i>'],
#  [1289.541, 1291.083, '<i>Are you lost, baby girl?</i>'],
#  [1293.541, 1294.5, '<i>You...</i>'],
#  [1303.541, 1304.458, '<i>Suck it.</i>'],
#  [1306.625, 1308.958, '<i>You had a bad reaction to the sedative.</i>'],
#  [1310.625, 1312.583, "<i>I didn't know you have a heart problem.</i>"],
#  [1315.458, 1316.708, '<i>Suck it yourself.</i>'],
#  [1319.625,
#   1323.125,
#   '<i>Why am I here? Who the fuck you are?\nAnd why are you keeping me here?</i>'],
#  [1323.875, 1324.791, '<i>Answer me.</i>'],
#  [1325.125,
#   1327.375,
#   "<i>- Sit. I don't want you to faint again.</i>\n- Answer me.</i>"],
#  [1327.458, 1329.291, "<i>- Sit down.\n- I'm not your property!</i>"],
#  [1329.375, 1330.833, '<i>Sit the fuck down.</i>'],
#  [1332.375, 1334.208, '<i>Do you wanna know why you are here,\nor not?</i>'],
#  [1342.666, 1345.083, '<i>Thank you.\nI think you should have a drink.</i>'],
#  [1356.833,
#   1359.583,
#   '<i>What I am about to tell you\nis so incredible that I...</i>'],
#  [1360.708,
#   1363.708,
#   "<i>I wouldn't have believed it's true\nuntil I saw you at the airport.</i>"],
#  [1367.041, 1369.083, '<i>In that moment, I understood that...</i>'],
#  [1369.833, 1371.25, "<i>it wasn't only my imagination.</i>"],
#  [1376.458, 1379.416, '<i>Five years ago,\nmy whole life was changed.</i>'],
#  [1382.916, 1384.375, '<i>My father died...</i>'],
#  [1385.375, 1386.75, '<i>in front of my eyes.</i>'],
#  [1389.125, 1391.166, '<i>The bullet went through his heart...</i>'],
#  [1391.75, 1393.125, '<i>and hit me.</i>'],
#  [1396.25, 1397.916, '<i>I thought I would die too.</i>'],
#  [1402.75, 1404.416, '<i>When my heart stop, I saw you.</i>'],
#  [1408.291,
#   1411.458,
#   '<i>Every day, I had this image\nin front of my eyes.</i>'],
#  [1416.333, 1418.375, '<i>I was looking for you around the world.</i>'],
#  [1421.666, 1423.125, '<i>Somewhere inside me,</i>'],
#  [1423.208, 1425.25, '<i>I had this feeling of certainty that...</i>'],
#  [1426.416,
#   1428.958,
#   '<i>one day you would stand in front of me\nand be mine.</i>'],
#  [1431.125, 1432.541, '<i>You must be kidding.</i>'],
#  [1433.333, 1435.75, "<i>Nobody owns me. I'm not an object.</i>"],
#  [1438.416,
#   1442.041,
#   "<i>You can't have me just like that;\nkidnap me and think that I'm all yours.</i>"],
#  [1444.0, 1444.833, '<i>I know.</i>'],
#  [1446.958,
#   1450.083,
#   "<i>But that's why I'm giving you\na chance to fall in love with me.</i>"],
#  [1451.458, 1453.166, '<i>Not because I made you do it,</i>'],
#  [1454.125, 1455.375, '<i>because you will want to.</i>'],
#  [1456.708,
#   1459.041,
#   "<i>But I've got a boyfriend\nwho is going to look for me.</i>"],
#  [1459.125, 1460.583, "<i>I've got family, friends...</i>"],
#  [1460.666, 1462.416, "<i>I've got my own life.</i>"],
#  [1462.5, 1464.833, "<i>I don't need a chance for love from you!</i>"],
#  [1465.25, 1468.583, '<i>So, I kindly ask you\nto let me the fuck out!</i>'],
#  [1492.916, 1494.666, "<i>Your boyfriend doesn't deserve you.</i>"],
#  [1498.375,
#   1500.833,
#   '<i>My people have taken your stuff\nfrom the room...</i>'],
#  [1502.708, 1504.125, '<i>and left a note for Martin.</i>'],
#  [1504.291, 1505.166, '<i>It says that...</i>'],
#  [1506.375, 1508.625, "<i>you're coming back to Poland,\nmoving out...</i>"],
#  [1510.5, 1511.875, '<i>disappearing from his life.</i>'],
#  [1513.958, 1515.0, '<i>You know what?</i>'],
#  [1515.916, 1516.958, '<i>Fuck off.</i>'],
#  [1532.5, 1534.75, "<i>I won't do anything\nwithout your permission.</i>"],
#  [1537.333, 1538.75, "<i>I'll wait until you want me,</i>"],
#  [1540.25, 1542.291, '<i>you desire me,\nand come to me yourself.</i>'],
#  [1544.541, 1545.666, "<i>I won't tie you up,</i>"],
#  [1546.208, 1547.291, "<i>but don't provoke me.</i>"],
#  [1547.625, 1548.75, "<i>I can't be gentle.</i>"],
#  [1549.833, 1552.208, "<i>I'm not used to tolerating disobedience.</i>"],
#  [1566.0, 1567.833, '<i>You have 365 days.</i>'],
#  [1569.916,
#   1572.166,
#   "<i>I'd do anything\nso you can fall in love with me.</i>"],
#  [1573.583,
#   1576.625,
#   "<i>If next year, on your birthday,\nnothing change, I'll set you free.</i>"],
#  [1589.875, 1590.833, '<i>Okay.</i>'],
#  [1591.708, 1593.458, '<i>Now, you put down the gun...</i>'],
#  [1594.75, 1596.5, '<i>or this will be stop being funny.</i>'],
#  [1603.375, 1604.916, '<i>Do you really wanna kill me?</i>'],
#  [1605.583, 1607.708, "<i>Many have tried. It's not that easy.</i>"],
#  [1608.25, 1609.583, '<i>Excuse me.</i>'],
#  [1610.416, 1611.875, "<i>There's been a delivery.</i>"],
#  [1612.666, 1614.208, '<i>You need to sign.</i>'],
#  [1622.583, 1623.666, '<i>Take her to her room.</i>'],
#  [1632.625, 1633.958, "<i>Okay, let's go.</i>"],
#  [1640.875, 1643.0, '<i>Massimo.\nThere will be problems.</i>'],
#  [1643.083, 1644.791, '<i>The conflict with the Gattuso family</i>'],
#  [1645.375, 1646.75, '<i>might ruin the business.</i>'],
#  [1647.375, 1648.541, '<i>Mind your own business.</i>'],
#  [1649.083,
#   1654.833,
#   "<i>I'm doing it. It is my duty\nto protect the family and you.</i>"],
#  [1655.041, 1656.666, '<i>Even from yourself.</i>'],
#  [1658.875, 1659.833, '<i>Shoot me.</i>'],
#  [1662.125, 1663.541, '<i>Get everyone here.</i>'],
#  [1722.375, 1724.041, '<i>Here comes Massimo the Great.</i>'],
#  [1725.041,
#   1728.25,
#   '<i>What are you going to do to me? Beat me?\nCut off my balls?</i>'],
#  [1739.0,
#   1741.5,
#   "<i>If you'd only stolen from me,\nyou'd be off the hook now.</i>"],
#  [1742.083,
#   1744.291,
#   '<i>But you decided to sell children\nto a brothel.</i>'],
#  [1749.416, 1751.208, "<i>Did you think I wouldn't find out?</i>"],
#  [1752.625,
#   1755.208,
#   '<i>- We all have skeletons in the closet...\n- Shut up.</i>'],
#  [1757.666,
#   1759.916,
#   '<i>You have smeared\nthe name of this family, Alfredo.</i>'],
#  [1760.708, 1761.541, '<i>What family?</i>'],
#  [1762.333, 1763.166, '<i>What values?</i>'],
#  [1764.041, 1765.916, '<i>Spare me this bullshit, and shoot me.</i>'],
#  [1774.958, 1776.0, '<i>You will be erased.</i>'],
#  [1776.208, 1778.291, '<i>No trace will be left of you...</i>'],
#  [1779.25, 1780.541, '<i>as if you never existed.</i>'],
#  [1784.166, 1785.666, "<i>That's your punishment.</i>"],
#  [1828.916, 1830.5, '<i>You see those marks?</i>'],
#  [1830.583, 1832.166, '<i>- Unbelievable.\n- The scumbag.</i>'],
#  [1837.375, 1838.25, '<i>Fuck.</i>'],
#  [1853.541, 1854.916, '<i>How are you feeling?</i>'],
#  [1858.5, 1859.875, "<i>You shouldn't have seen it.</i>"],
#  [1861.416, 1863.5, '<i>But you have to know that he deserved it.</i>'],
#  [1864.625, 1866.125, '<i>He had been hurting children.</i>'],
#  [1866.666, 1868.625, '<i>Cheating and stealing on his family.</i>'],
#  [1869.166, 1870.291, "<i>We don't forgive it.</i>"],
#  [1871.708, 1873.875, "<i>He killed himself\nwith what he'd been doing.</i>"],
#  [1879.791,
#   1882.291,
#   "<i>It wasn't me who changed your clothes.\nIt was the maid.</i>"],
#  [1883.25, 1884.833, '<i>You have people for everything.</i>'],
#  [1887.0,
#   1890.625,
#   "<i>It's... It's one of the advantages\nof being a boss.</i>"],
#  [1897.625,
#   1900.875,
#   '<i>So, tell one of your butlers\nto bring my cell phone and laptop.</i>'],
#  [1903.833, 1905.5, "<i>I can see you've got your strength back.</i>"],
#  [1907.458, 1909.333, '<i>You will have your cell phone\nand your laptop</i>'],
#  [1909.416, 1910.708, "<i>when it's the right time.</i>"],
#  [1912.833, 1913.666, '<i>Now...</i>'],
#  [1914.666,
#   1917.25,
#   '<i>if you need anything,\nDomenico is here to help you.</i>'],
#  [1922.333,
#   1924.625,
#   '<i>Be ready in two hours,\nbecause we need to buy some stuff</i>'],
#  [1924.708, 1925.833, '<i>before we depart.</i>'],
#  [1925.916, 1929.333, '<i>Depart? Where to?\nWhat are you talking about?</i>'],
#  [1929.416, 1931.791, "<i>I'm not flying anywhere,\nunless it's Poland.</i>"],
#  [1934.25, 1935.583, "<i>It wasn't an offer;</i>"],
#  [1936.208, 1938.416, '<i>- it was an order.\n- Listen to me,</i>'],
#  [1938.5, 1939.791, "<i>I'm not a bag of potatoes</i>"],
#  [1939.875, 1942.125, '<i>that you can transfer\nwithout my permission.</i>'],
#  [1942.208,
#   1944.416,
#   "<i>If that's your idea of\nhow falling in love with you looks,</i>"],
#  [1944.5, 1945.458, "<i>you're fucking wrong.</i>"],
#  [1956.833, 1958.291, '<i>If you hit me again...</i>'],
#  [1958.375, 1960.708, '<i>What? You will kill me?</i>'],
#  [1966.708, 1968.333, '<i>This is what you call a temper?</i>'],
#  [1969.333, 1971.041, "<i>How come you're not Italian?</i>"],
#  [1971.375, 1973.125, '<i>How many Polish girls do you know?</i>'],
#  [1974.75, 1976.875, '<i>It looks like one is all I need to know.</i>'],
#  [1981.375, 1982.625, '<i>It will be a good year.</i>'],
#  [1984.375, 1985.541, '<i>I just need to react quicker,</i>'],
#  [1985.625, 1988.0, "<i>'cause I lose my vigilance\nwhen I'm around you.</i>"],
#  [1993.333, 1994.791, '<i>Domenico brought all of your stuff.</i>'],
#  [1997.375,
#   1999.833,
#   '<i>Impressive amount of shoes\nfor a five-day holiday.</i>'],
#  [2009.958, 2012.916, "<i>♪ The radio\nThe radio's about to explode ♪</i>"],
#  [2013.0,
#   2017.041,
#   "<i>♪ Oh, baby\nDon't waste your time or our lives\xa0♪</i>"],
#  [2017.125, 2020.0, "<i>♪ The radio\nThe radio's about to explode\xa0♪</i>"],
#  [2020.083, 2023.625, "<i>♪ I have to have my dose now\nOr I'll die\xa0♪</i>"],
#  [2024.708, 2026.25, '<i>Breakfast is ready, miss.</i>'],
#  [2030.333, 2031.791, "<i>I'll do my best to help you.</i>"],
#  [2034.166, 2036.583, '<i>I think your boss wants me to gain weight.</i>'],
#  [2036.666,
#   2040.166,
#   '<i>I think he just wants\nto take good care of you, you know?</i>'],
#  [2041.083,
#   2044.416,
#   "<i>But I think you're here to help me\nwith everything what I need.</i>"],
#  [2044.958, 2046.208, '<i>So, I need you to sit down...</i>'],
#  [2047.208, 2048.5, '<i>and help me to eat.</i>'],
#  [2050.166, 2051.0, '<i>Okay.</i>'],
#  [2051.083, 2054.125, '<i>♪ Love me, love me\nLove me now\xa0♪</i>'],
#  [2054.708, 2057.583, '<i>♪ Touch me, touch me\nTouch me now ♪</i>'],
#  [2058.041, 2060.208, '<i>♪ Let me check inside you\xa0♪</i>'],
#  [2062.458, 2064.666, '<i>Today, I have some business\nto take care of.</i>'],
#  [2065.916, 2067.25, '<i>You will accompany me.</i>'],
#  [2067.708, 2069.291, "<i>I said, I'm not going anywhere.</i>"],
#  [2070.125, 2073.125, '<i>♪ Baby, my mind is on ready now\xa0♪</i>'],
#  [2073.583, 2076.625, '<i>♪ Baby, my mind is on ready now\xa0♪</i>'],
#  [2077.041,
#   2080.25,
#   "<i>♪ Lady, tell me something\n'Cause I need somebody...\xa0♪</i>"],
#  [2080.833, 2081.708, '<i>Etna.</i>'],
#  [2082.75, 2084.333, '<i>Known also as "Mongibello,"</i>'],
#  [2085.416, 2086.5, '<i>"beautiful mountain."</i>'],
#  [2088.25,
#   2091.416,
#   '<i>Legend says\nthat Zeus used to hide Typhon there...</i>'],
#  [2093.041, 2094.583, '<i>a monster of 100 heads...</i>'],
#  [2094.666, 2096.625, "<i>and that it's still trying to escape.</i>"],
#  [2098.416,
#   2102.75,
#   "<i>So, Typhon didn't fall in love\nwith Zeus in 365 days.</i>"],
#  [2110.125, 2111.666, '<i>♪ Yeah\xa0♪</i>'],
#  [2113.333, 2115.625, '<i>♪ Whoa, yeah\xa0♪</i>'],
#  [2117.5,
#   2120.541,
#   "<i>♪ Lady, tell me something\n'Cause I need somebody ♪</i>"],
#  [2120.625, 2124.041, '<i>♪ Treat me as your boo, treat\nLittle child ♪</i>'],
#  [2124.125,
#   2127.333,
#   "<i>♪ Lady, tell me something\n'Cause I need somebody ♪</i>"],
#  [2127.416, 2131.416, '<i>♪ Treat me as your boo, treat\nLittle child ♪</i>'],
#  [2131.5, 2133.625, "<i>♪ Livin' in the dark room\xa0♪</i>"],
#  [2133.708, 2136.625, "<i>♪ Yes, I'm livin' in the dark room\xa0♪</i>"],
#  [2137.208, 2140.416, "<i>♪ 'Cause I'm livin' in the dark room ♪</i>"],
#  [2140.5, 2143.916, '<i>♪ Save me from this fucking dark room\xa0♪</i>'],
#  [2144.0, 2145.333, '<i>♪ Yeah\xa0♪</i>'],
#  [2145.416, 2147.458, "<i>♪ Livin' in the dark room\xa0♪</i>"],
#  [2147.541, 2151.041, "<i>♪ Yes, I'm livin' in the dark room\xa0♪</i>"],
#  [2151.125, 2154.333, "<i>♪ 'Cause I'm livin' in the dark room ♪</i>"],
#  [2154.708, 2157.708, '<i>♪ Save me from this fucking dark room\xa0♪</i>'],
#  [2158.75, 2159.625, '<i>Get out!</i>'],
#  [2159.875, 2161.833, '<i>- Get out, or else I...\n- Else what?</i>'],
#  [2177.625,
#   2180.666,
#   "<i>Or I guarantee you,\nthis is the last time you'll see it.</i>"],
#  [2188.916, 2190.375, "<i>I've order it,</i>"],
#  [2191.541,
#   2194.166,
#   "<i>and I'm gonna decide\nwhen I'm going to see it.</i>"],
#  [2206.041, 2207.458, '<i>See it on yourself.</i>'],
#  [2210.708, 2211.875, '<i>No, wait.</i>'],
#  [2229.333, 2231.666, '<i>Please, I need help.\nCan you help me?</i>'],
#  [2231.75, 2233.958, '<i>Someone kidnapped me, and I need help.</i>'],
#  [2234.041, 2235.0, '<i>Can you help me?</i>'],
#  [2237.25, 2238.458, '<i>Good morning, sir.</i>'],
#  [2248.333, 2250.0, '<i>Are you lost, baby girl?</i>'],
#  [2259.333,
#   2262.333,
#   '<i>If you feel like running,\nyou should wear a different kind of shoes.</i>'],
#  [2264.916, 2266.875, '<i>Sometimes, fighting is futile.</i>'],
#  [2268.333, 2270.041, '<i>You have to accept the situation.</i>'],
#  [2271.125, 2272.708, '<i>The faster, the better for you.</i>'],
#  [2274.833,
#   2279.666,
#   '<i>You can either make it hard\nfor both of us for the next year, or...</i>'],
#  [2280.5,
#   2283.0,
#   '<i>take part in an adventure\nthat fate has given you.</i>'],
#  [2283.208, 2284.291, "<i>It wasn't fate;</i>"],
#  [2285.0, 2285.916, '<i>it was you.</i>'],
#  [2287.541, 2289.75, '<i>Sometimes, we have to make our own luck.</i>'],
#  [2294.916, 2296.625, '<i>Is it true what you said earlier?</i>'],
#  [2301.333, 2302.25, '<i>What do you mean?</i>'],
#  [2304.0, 2306.416, "<i>That you won't touch me\nwithout my permission.</i>"],
#  [2308.458, 2310.333, "<i>I'm not the monster you think I am.</i>"],
#  [2313.916, 2317.0, '<i>I want my cell phone and laptop. Now.</i>'],
#  [2318.458, 2320.125, '<i>And something normal for dinner.</i>'],
#  [2321.25, 2322.208, '<i>Pierogi.</i>'],
#  [2326.791, 2329.833, '<i>♪ You made a monster\xa0♪</i>'],
#  [2333.291, 2335.041, '<i>♪ You made a ♪</i>'],
#  [2335.416,
#   2339.5,
#   '<i>- ♪ You made a monster\xa0♪\n- ♪ Stitch by stitch\xa0♪</i>'],
#  [2339.583, 2340.75, '<i>♪ You made a ♪</i>'],
#  [2340.833, 2343.625, '<i>♪ You patch me up then tear me down\xa0♪</i>'],
#  [2343.708,
#   2348.208,
#   '<i>- ♪ You made a monster\xa0♪\n- ♪ Stitch by stitch\xa0♪</i>'],
#  [2348.291, 2349.833, '<i>♪ You made a ♪</i>'],
#  [2351.833,
#   2355.708,
#   '<i>- ♪ Stitch by stitch\xa0♪\n- ♪ You made a monster\xa0♪</i>'],
#  [2356.541, 2357.708, '<i>♪ Monster\xa0♪\xa0</i>'],
#  [2366.625, 2368.375, "<i>- You look...\n- I'm starving.</i>"],
#  [2383.875, 2384.75, '<i>As you wished...</i>'],
#  [2386.416, 2387.25, '<i>pierogi.</i>'],
#  [2396.375, 2397.208, '<i>Is it good?</i>'],
#  [2398.708, 2400.333, '<i>My grandma makes them better.</i>'],
#  [2402.625, 2404.291, "<i>But you don't have to kill him.</i>"],
#  [2405.5, 2407.375, '<i>I will give him couple of lessons.</i>'],
#  [2416.5, 2418.083, '<i>So, what do you actually do?</i>'],
#  [2422.791, 2424.041, '<i>ANNA\nWHY ARE YOU NOT REPLYING?</i>'],
#  [2424.125, 2425.125, "<i>I'M NOT GIVING UP!</i>"],
#  [2425.208, 2426.083, '<i>I do...</i>'],
#  [2427.958, 2428.791, '<i>business.</i>'],
#  [2429.958, 2430.791, '<i>Hmm.</i>'],
#  [2431.416, 2432.583, "<i>Massimo, I'm serious.</i>"],
#  [2433.708,
#   2436.458,
#   '<i>You want me to accept\na year-long declaration,</i>'],
#  [2437.416, 2439.416, "<i>I have rights to know\nwhat's waiting for me.</i>"],
#  [2439.5, 2441.333, '<i>You will know\nexactly what you need to know.</i>'],
#  [2443.541, 2445.25, '<i>I have few...</i>'],
#  [2446.041, 2447.041, '<i>companies,</i>'],
#  [2448.416, 2450.625, '<i>hotels, clubs, restaurants.</i>'],
#  [2453.0, 2455.0, "<i>It's like a corporation,</i>"],
#  [2455.541, 2456.416, "<i>and I'm the CEO.</i>"],
#  [2459.291, 2461.416, '<i>The whole is a part of a bigger operation.</i>'],
#  [2461.5, 2463.708, '<i>But the details are useless...</i>'],
#  [2465.083, 2466.041, '<i>and dangerous.</i>'],
#  [2467.541,
#   2470.416,
#   "<i>I was chosen the head of this family\nafter my dad's death.</i>"],
#  [2472.625, 2474.166, '<i>It was not what I wished for.</i>'],
#  [2474.791, 2475.791, '<i>I had no choice.</i>'],
#  [2478.666, 2479.875, '<i>Exactly like me.</i>'],
#  [2480.916, 2482.708, '<i>I would never have come to Sicily.</i>'],
#  [2486.875, 2488.083, "<i>You'll change your mind.</i>"],
#  [2489.833, 2491.458, '<i>You just have to...</i>'],
#  [2492.541, 2493.833, '<i>help me a little.</i>'],
#  [2494.291, 2495.166, '<i>Help?</i>'],
#  [2516.625, 2518.791, "<i>I'd like you...</i>"],
#  [2520.416, 2521.291, '<i>to teach me...</i>'],
#  [2523.125, 2524.166, '<i>how to be gentle...</i>'],
#  [2526.958, 2527.833, '<i>for you.</i>'],
#  [2533.916, 2536.208, '<i>♪ You\xa0♪</i>'],
#  [2537.958, 2540.208, '<i>♪ You\xa0♪</i>'],
#  [2541.958, 2544.333, '<i>♪ You\xa0♪</i>'],
#  [2544.666, 2546.833, '<i>♪ Ooh-ooh\xa0♪</i>'],
#  [2550.125, 2555.25, '<i>♪ I feel the weight upon my chest\xa0♪</i>'],
#  [2558.0, 2563.708, '<i>♪ Suffocating\xa0of my lies\xa0♪</i>'],
#  [2566.083, 2571.0, "<i>♪ How do I know it's life? ♪</i>"],
#  [2573.625, 2579.166, "<i>♪ I get it every time you're near\xa0♪</i>"],
#  [2581.833, 2584.458, '<i>♪ You\xa0♪</i>'],
#  [2585.833, 2588.5, '<i>♪ You... ♪</i>'],
#  [2589.5, 2590.625, '<i>Mom.</i>'],
#  [2591.375, 2593.041, '<i>Yeah, everything is fine.</i>'],
#  [2593.416,
#   2597.583,
#   '<i>I have to tell you something, though.\nI was offered a new job in Sicily.</i>'],
#  [2598.375, 2599.916, "<i>It's the best hotel on the island.</i>"],
#  [2600.0, 2602.0, '<i>I was given a yearly contract.</i>'],
#  [2603.125, 2605.291, "<i>Come on, stop worrying. You'll see.</i>"],
#  [2605.375,
#   2608.166,
#   "<i>You'll come to visit\nand fall in love with the place as I have.</i>"],
#  [2700.833, 2702.166, "<i>We're leaving today.</i>"],
#  [2702.75, 2705.166, "<i>We'll be guests\nat a few offshore parties,</i>"],
#  [2705.25,
#   2707.958,
#   '<i>so take that under consideration\nwhile packing your bag.</i>'],
#  [2714.416,
#   2716.958,
#   "<i>Do you want anything from me,\nor you're just looking?</i>"],
#  [2730.541, 2732.041, '<i>Why are you looking at it?</i>'],
#  [2735.75, 2736.958, '<i>Do you wanna touch it?</i>'],
#  [2738.041, 2741.0, '<i>♪ Say what you think\xa0♪</i>'],
#  [2743.333, 2746.291, '<i>♪ Oh, baby, I could lose my mind\nYeah ♪</i>'],
#  [2746.833, 2749.541, '<i>♪ You know that I can lose my mind\nYeah ♪</i>'],
#  [2749.625, 2751.916, '<i>♪ What do you want me to be?\xa0♪</i>'],
#  [2752.916,
#   2756.291,
#   '<i>- ♪ Headlight, hold tight\xa0♪\n- ♪ No, no, no, no\xa0♪</i>'],
#  [2756.708,
#   2759.875,
#   "<i>♪ Oh, baby\nYou know I've been thinking about it\xa0♪</i>"],
#  [2760.625,
#   2763.541,
#   "<i>♪ You know that\nI've been dreaming about it\xa0♪</i>"],
#  [2765.666,
#   2769.791,
#   "<i>♪ You know the deal\nDon't make any promises\xa0♪</i>"],
#  [2770.125, 2771.416, '<i>♪ Promises\xa0♪</i>'],
#  [2771.875, 2773.458, '<i>- ♪ Got me ♪\n- ♪ Got me ♪</i>'],
#  [2773.541, 2775.083, "<i>- ♪ Flyin' ♪\n- ♪ Flyin' ♪</i>"],
#  [2775.166, 2776.541, '<i>♪ High\xa0♪</i>'],
#  [2777.041, 2778.208, '<i>Baby girl...</i>'],
#  [2779.458,
#   2782.791,
#   '<i>when your entire life is based on\ntaking everything with force,</i>'],
#  [2782.875, 2785.0, "<i>it's hard to react in a different way.</i>"],
#  [2785.875,
#   2789.5,
#   '<i>Especially if someone is taking away\na pleasure you really desire...</i>'],
#  [2792.833, 2794.166, "<i>Don't provoke me.</i>"],
#  [2796.458, 2797.5, '<i>Or what?</i>'],
#  [2827.083, 2828.791, "<i>She's got quite a temper.</i>"],
#  [2833.291, 2834.75, "<i>At least I won't get bored.</i>"],
#  [2835.916, 2838.25, '<i>Good luck, Massimo.</i>'],
#  [2842.833, 2843.875, "<i>Let's go.</i>"],
#  [2852.916, 2854.375, '<i>You comfortable enough?</i>'],
#  [2855.041,
#   2858.458,
#   "<i>Just untie me,\nyou fucking wop, and I'll show you...</i>"],
#  [2858.541, 2859.75, '<i>English, please.</i>'],
#  [2901.75, 2903.416, '<i>You have to earn the pleasure.</i>'],
#  [2938.25, 2939.375, '<i>Laura.</i>'],
#  [2945.083,
#   2948.416,
#   '<i>♪ Good things are boring\nI get antsy inside\xa0♪</i>'],
#  [2948.5, 2949.791, "<i>♪ It's all right\xa0♪</i>"],
#  [2950.583, 2951.875, "<i>♪ It's all right\xa0♪</i>"],
#  [2953.583,
#   2957.083,
#   '<i>♪ But I need the sounds of birds\nSo I can feel alive\xa0♪</i>'],
#  [2957.166, 2958.541, "<i>♪ It's all right\xa0♪</i>"],
#  [2959.291, 2960.625, "<i>♪ It's all right\xa0♪</i>"],
#  [2962.833,
#   2965.958,
#   "<i>♪ Something's changing\nSomething we can't see\xa0♪</i>"],
#  [2966.458, 2969.416, "<i>♪ 'Cause I'm from another world\xa0♪</i>"],
#  [2971.291,
#   2974.375,
#   '<i>♪ This thing is darker\nThan the deep blue sea ♪</i>'],
#  [2975.291, 2978.083, "<i>♪ I don't think I can be your girl... ♪</i>"],
#  [2984.541, 2986.541, '<i>The problem is,</i>'],
#  [2986.625, 2988.791, '<i>after the elections...</i>'],
#  [2991.958, 2993.5, '<i>the whole deal might blow up.</i>'],
#  [2995.875, 2997.541, '<i>We just need to pay them more.</i>'],
#  [3000.75, 3003.041, '<i>Did you find her? Did you?</i>'],
#  [3003.625, 3005.416, '<i>And how is she?</i>'],
#  [3006.416, 3007.541, '<i>Are you happy?</i>'],
#  [3009.291, 3010.5, '<i>Like everything.</i>'],
#  [3011.75, 3012.666, "<i>It's difficult.</i>"],
#  [3017.208, 3018.291, '<i>It always is.</i>'],
#  [3024.75, 3026.5, '<i>Are you talking about me?</i>'],
#  [3028.041,
#   3032.416,
#   "<i>I've just said to my cousin\nthat you're a marvelous, gentle woman.</i>"],
#  [3032.541, 3033.666, '<i>- Yeah.\n- Yeah.</i>'],
#  [3034.0, 3034.958, '<i>Mm-hmm.</i>'],
#  [3038.916, 3040.0, '<i>Can you stop it?</i>'],
#  [3042.541, 3043.375, '<i>Mmm.</i>'],
#  [3044.75, 3045.708, "<i>I'm bored.</i>"],
#  [3047.833, 3049.333, "<i>- I'm dirty.\n- Stop it.</i>"],
#  [3062.541, 3064.5, '<i>Is she going to bathe\nin the fountain?</i>'],
#  [3064.916, 3067.5, "<i>- No, she isn't.\n- Is she?</i>"],
#  [3068.583, 3070.125, '<i>- No.\n- Wanna bet?</i>'],
#  [3071.333, 3072.875, "<i>No, she won't do it.</i>"],
#  [3081.0, 3082.833, "<i>Couldn't you use the bathroom?</i>"],
#  [3082.916, 3084.083, '<i>Fountain was closer.</i>'],
#  [3085.75, 3086.625, '<i>Of course.</i>'],
#  [3141.75, 3142.958, '<i>Fuck!</i>'],
#  [3145.791,
#   3149.416,
#   '<i>Which period is that?\nEarly Michelangelo or late Caravaggio?</i>'],
#  [3151.625, 3152.666, '<i>It was a gift.</i>'],
#  [3153.583, 3154.708, '<i>Yeah, sure.</i>'],
#  [3155.541, 3157.541, "<i>Not that you're a megalomaniac.</i>"],
#  [3162.75, 3164.541, '<i>The great Massimo,</i>'],
#  [3165.208, 3167.416, '<i>the slayer of lions and tiny women.</i>'],
#  [3168.958, 3169.875, '<i>Stop it.</i>'],
#  [3184.958, 3186.375, "<i>Maybe I don't want to stop.</i>"],
#  [3202.916, 3204.625, '<i>- Take it.</i>'],
#  [3205.708, 3206.875, '<i>In your dreams.</i>'],
#  [3208.041, 3209.125, '<i>Are you saying no?</i>'],
#  [3210.75, 3212.416, '<i>You have people for everything.</i>'],
#  [3212.833, 3214.125, '<i>So, let them to this.</i>'],
#  [3216.333, 3217.291, '<i>Are you sure?</i>'],
#  [3237.916, 3239.666, '<i>Open the door. I want to leave.</i>'],
#  [3240.75, 3242.916, '<i>Let me out. Open the door.</i>'],
#  [3245.625, 3247.416, '<i>- Open this fucking door.\n- Shh...</i>'],
#  [3263.541, 3265.166, '<i>- Sit on the bed.</i>'],
#  [3283.0, 3284.208, '<i>Fuck!</i>'],
#  [3293.166, 3294.166, '<i>Fuck!</i>'],
#  [3317.041, 3318.791, "<i>I'll do anything I want with you.</i>"],
#  [3324.208, 3325.875, '<i>I was hoping you would do that.</i>'],
#  [3328.833, 3330.375, "<i>It's a telescopic tube.</i>"],
#  [3332.791, 3335.291, '<i>Every time you move,\nit widens more and more.</i>'],
#  [3349.75, 3351.791, "<i>I'm gonna show you what you're missing.</i>"],
#  [3451.333, 3452.583, '<i>You\xa0see, Laura...</i>'],
#  [3461.458, 3462.458, '<i>at this moment,</i>'],
#  [3463.666, 3465.458, "<i>you're immobilized enough...</i>"],
#  [3466.458, 3468.25, "<i>that you can't resist me anymore.</i>"],
#  [3473.208, 3474.625, '<i>At the same time...</i>'],
#  [3476.75,
#   3480.791,
#   '<i>I have access\nto absolutely every bit of your body.</i>'],
#  [3493.166, 3494.208, '<i>Please...</i>'],
#  [3501.625, 3503.041, '<i>Are you asking me to begin?</i>'],
#  [3514.125, 3515.958, "<i>I'm gonna fuck you so hard...</i>"],
#  [3517.25, 3519.416, '<i>that they will hear you scream in Warsaw.</i>'],
#  [3519.5, 3520.75, "<i>I'm begging you.</i>"],
#  [3547.791, 3548.708, '<i>Dress up.</i>'],
#  [3549.416, 3551.75, '<i>We need to be in one of my clubs\nin two hours.</i>'],
#  [3576.291, 3578.708, '<i>♪ Here she comes again\xa0♪</i>'],
#  [3579.666, 3582.416, "<i>♪ With worries she can't hide... ♪</i>"],
#  [3583.708, 3584.75, '<i>Listen to me.</i>'],
#  [3585.5, 3586.666, "<i>He's gonna kill you.</i>"],
#  [3587.291, 3589.458, "<i>And then, he's gonna kill me.</i>"],
#  [3589.541, 3590.666, '<i>Shall we?</i>'],
#  [3591.333, 3593.75, '<i>♪ Who can keep her sane?\xa0♪</i>'],
#  [3594.625, 3597.5, '<i>♪ Give her peace of mind?\xa0♪</i>'],
#  [3606.083, 3607.083, '<i>Listen, Laura.</i>'],
#  [3607.708, 3608.916, "<i>We won't be alone, okay?</i>"],
#  [3609.25, 3610.5, '<i>Some people will join us,</i>'],
#  [3610.583,
#   3612.541,
#   '<i>and we will have to discuss\nsome matters with them.</i>'],
#  [3613.416, 3614.875, '<i>"Some people, some matters."</i>'],
#  [3615.375, 3617.541, "<i>You are going to play Mafia, aren't you?</i>"],
#  [3621.666, 3622.791, '<i>Listen, Laura.</i>'],
#  [3623.416, 3625.666, '<i>This is not a fucking joke, okay?</i>'],
#  [3626.25, 3627.5, '<i>Just keep your head down.</i>'],
#  [3639.291, 3640.541, '<i>Hi, gorgeous.</i>'],
#  [3641.75, 3644.791, '<i>Okay, you wait here.\nJust one minute.</i>'],
#  [3693.416, 3694.791, '<i>What the hell are you wearing?</i>'],
#  [3695.541, 3697.458, '<i>A couple thousand euro of yours.</i>'],
#  [3709.875, 3710.916, "<i>Don't provoke me.</i>"],
#  [3712.791, 3713.666, '<i>Why?</i>'],
#  [3715.625, 3717.958, '<i>Are you afraid that I am too good at it?</i>'],
#  [3719.5, 3721.083, '<i>My dress is so short,</i>'],
#  [3721.166,
#   3723.875,
#   '<i>and could get inside me\nwithout taking it off.</i>'],
#  [3730.416, 3732.833, '<i>You will be mine. I guarantee it.</i>'],
#  [3733.833, 3735.666, "<i>Then I'll do anything I want,</i>"],
#  [3736.125, 3738.125, '<i>anytime I want with you.</i>'],
#  [3739.333, 3740.583, '<i>Keep on dreaming.</i>'],
#  [3758.916,
#   3761.291,
#   '<i>♪ You heard the beat\nGot the world on a string\xa0♪</i>'],
#  [3761.625, 3763.958, "<i>♪ To live forever\nYou'll do anything\xa0♪</i>"],
#  [3764.375, 3766.666, '<i>♪ Hatch your eggs\nGrab the diamond ring\xa0♪</i>'],
#  [3767.083, 3769.375, '<i>♪ This is our night\nTo do everything\xa0♪</i>'],
#  [3770.541, 3771.416, '<i>♪ Oh\xa0♪</i>'],
#  [3773.333, 3775.416, "<i>♪ It's the time of our lives\xa0♪</i>"],
#  [3780.625, 3783.0, '<i>♪ I like the way that your looking at me\xa0♪</i>'],
#  [3783.375, 3785.75, '<i>♪ I like the way it falls in between\xa0♪</i>'],
#  [3786.25, 3788.416, '<i>♪ Getting lost, get lost in me\xa0♪</i>'],
#  [3788.958,
#   3791.375,
#   "<i>♪ Take a ride\nAnd you'll start to believe\xa0♪</i>"],
#  [3791.791, 3794.333, '<i>♪ Ohh\xa0♪</i>'],
#  [3794.416, 3797.875, '<i>♪ This is the time of our lives\xa0♪</i>'],
#  [3824.166, 3826.166, '<i>♪ Music, music, music, cigarette... ♪</i>'],
#  [3836.083, 3838.291, "<i>♪ It's all over, yeah\xa0♪</i>"],
#  [3838.791, 3841.125, "<i>♪ It's the time of our lives\xa0♪</i>"],
#  [3842.791, 3844.625, '<i>Finally, a real whore.</i>'],
#  [3845.875,
#   3850.208,
#   "<i>I'm going to fuck you so hard,\nyou won't be able to sit.</i>"],
#  [3850.666, 3851.75, '<i>Come here.</i>'],
#  [3852.416, 3854.666, '<i>- Come here.</i>'],
#  [3855.125, 3856.916, '<i>- Fuck!</i>'],
#  [3859.0, 3860.083, '<i>Get out!</i>'],
#  [3873.875, 3876.291, '<i>I told you a thousand times.</i>'],
#  [3876.375, 3877.333, '<i>Enough!</i>'],
#  [3878.125, 3879.666, '<i>Just do your fucking duty.</i>'],
#  [3881.958, 3885.041, '<i>Are you aware who you have shot, Massimo?</i>'],
#  [3886.291, 3888.5, "<i>Do you know what you've done?</i>"],
#  [3889.291, 3891.041, "<i>I couldn't just\nsit there and watch.</i>"],
#  [3891.458,
#   3894.791,
#   '<i>This means war.\nA war between two powerful families.</i>'],
#  [3894.875, 3895.791, '<i>Do you get that?</i>'],
#  [3898.833,
#   3903.25,
#   '<i>The only thing you can do\nis to get rid of Laura.</i>'],
#  [3903.708, 3905.875, '<i>Do that and ask Anna for forgiveness.</i>'],
#  [3907.041, 3909.541, '<i>And get rid of this damn boat, too.</i>'],
#  [3911.083, 3912.833, '<i>Hey! Watch your fucking mouth!</i>'],
#  [3914.041, 3915.416, "<i>I'm sorry.</i>"],
#  [3918.541, 3919.541, "<i>You're sorry?</i>"],
#  [3922.041, 3923.75, "<i>I'm sorry, I didn't think...</i>"],
#  [3923.833, 3925.291, "<i>Yeah, you </i>didn't think.</i>"],
#  [3927.75, 3929.625, "<i>What's going on? Did you kill him?</i>"],
#  [3929.708,
#   3931.833,
#   "<i>- It's none of your business.\n- You killed him?</i>"],
#  [3931.916,
#   3934.916,
#   "<i>I shot his hands.\nI wouldn't have had to do it</i>"],
#  [3935.0,
#   3937.625,
#   "<i>if you didn't dress like a whore\nand put on your little show.</i>"],
#  [3939.0,
#   3941.791,
#   "<i>So, that's my fault\nthat your friend tried to rape me?</i>"],
#  [3941.875, 3943.041, "<i>That's my fault?</i>"],
#  [3943.875, 3944.75, '<i>Fuck off.</i>'],
#  [3945.291, 3946.166, '<i>Enough.</i>'],
#  [3958.166, 3959.875, '<i>- Laura.\n- Fuck off!</i>'],
#  [3959.958,
#   3962.125,
#   '<i>- Fuck off!\xa0Leave me alone.\n- Where you going?</i>'],
#  [3962.208,
#   3964.5,
#   '<i>- Stop it. Where are you going?\n- No. Get off me.</i>'],
#  [3964.583, 3965.875, '<i>Laura, where are you going?</i>'],
#  [3965.958, 3966.833, '<i>Fuck you.</i>'],
#  [3966.916, 3968.125, '<i>- Can you stop that?\n- Fuck!</i>'],
#  [3968.208, 3969.041, '<i>Stop it!</i>'],
#  [3969.125, 3970.666, "<i>- Don't touch me! Fuck you!\n- Stop it!</i>"],
#  [3971.125, 3972.291, '<i>- What are you doing?\n- Fuck!</i>'],
#  [3974.458, 3975.5, '<i>Fuck!</i>'],
#  [3989.375, 3990.416, '<i>Laura!</i>'],
#  [3990.916, 3992.791, '<i>Laura, breathe! Breathe.</i>'],
#  [3993.125, 3994.375, '<i>Hey. Hey.</i>'],
#  [3995.916, 3996.75, '<i>Okay?</i>'],
#  [4020.875, 4022.958, "<i>I'm so grateful\nthat you're alive.</i>"],
#  [4023.041, 4025.041, '<i>But in the same time, I wanna kill you.</i>'],
#  [4026.541, 4027.5, '<i>You saved me.</i>'],
#  [4028.041, 4029.5, '<i>Thank God I was so close.</i>'],
#  [4031.958, 4033.5, '<i>Why are you so disobedient?</i>'],
#  [4034.833, 4035.791, "<i>I'm sorry.</i>"],
#  [4039.75, 4040.916, '<i>You have to understand...</i>'],
#  [4044.541, 4046.041, "<i>I won't do it anymore.</i>"],
#  [4049.041, 4051.458, "<i>I can't lose you. I don't want to.</i>"],
#  [4059.5, 4060.625, '<i>You have to rest.</i>'],
#  [4076.916, 4077.875, "<i>You're wet.</i>"],
#  [4086.25, 4087.291, "<i>Don't play with me.</i>"],
#  [4087.375, 4089.375, '<i>♪ Did you really think\xa0♪</i>'],
#  [4090.041, 4092.958, "<i>♪ I'd just forgive and forget?\xa0♪</i>"],
#  [4094.291, 4095.458, '<i>♪ No\xa0♪</i>'],
#  [4096.208, 4098.416, '<i>♪ After catching you with her\xa0♪</i>'],
#  [4098.5, 4101.083, '<i>♪ Your blood should run cold\xa0♪</i>'],
#  [4101.5, 4103.916, '<i>♪ So cold\xa0♪</i>'],
#  [4104.625, 4108.208, '<i>♪ You ♪</i>'],
#  [4109.0, 4112.708, '<i>♪ You two-timing, cheap, lying wannabe ♪</i>'],
#  [4113.0, 4116.916, "<i>♪ You're a fool\xa0♪</i>"],
#  [4118.0, 4121.833, "<i>♪ If you thought\nThat I'd just let this go ♪</i>"],
#  [4121.916, 4123.958, '<i>♪ I see red\xa0♪</i>'],
#  [4125.333, 4126.458, '<i>♪ Red\xa0♪</i>'],
#  [4126.75, 4129.375, '<i>♪ Oh, red\xa0♪</i>'],
#  [4130.666, 4133.291, '<i>♪ A gun to your head ♪</i>'],
#  [4134.416, 4135.833, '<i>♪ Head\xa0♪</i>'],
#  [4135.916, 4138.083, '<i>♪ To your head\xa0♪</i>'],
#  [4139.375, 4142.291, '<i>♪ Now all I see is red\xa0♪</i>'],
#  [4142.375, 4144.666, '<i>♪ Red, red\xa0♪</i>'],
#  [4146.666, 4148.916, '<i>♪ Did you really just say\xa0♪</i>'],
#  [4149.875, 4153.125, "<i>♪ She didn't mean anything?\xa0♪</i>"],
#  [4156.208, 4158.041, "<i>♪ I'll remember those words\xa0♪</i>"],
#  [4158.125, 4160.791, '<i>♪ When I come for your soul ♪</i>'],
#  [4161.125, 4163.125, '<i>♪ Your soul\xa0♪</i>'],
#  [4163.458, 4167.375, '<i>- ♪ Know that you ♪</i>'],
#  [4168.541, 4170.666, '<i>♪ You dug your own grave\xa0♪</i>'],
#  [4170.75, 4172.458, '<i>♪ Now lie in it\xa0♪</i>'],
#  [4172.541, 4176.541, "<i>♪ You're so cruel\xa0♪</i>"],
#  [4177.5, 4181.708, '<i>♪ But revenge is a dish best served cold ♪</i>'],
#  [4181.791, 4183.5, '<i>♪ I see red\xa0♪</i>'],
#  [4184.875, 4186.125, '<i>♪ Red\xa0♪</i>'],
#  [4186.208, 4189.375, '<i>♪ Oh, red\xa0♪</i>'],
#  [4190.708, 4193.041, '<i>♪ A gun to your head\xa0♪</i>'],
#  [4193.875, 4195.416, '<i>♪ Head\xa0♪</i>'],
#  [4195.5, 4197.333, '<i>♪ To your head\xa0♪</i>'],
#  [4198.958, 4200.125, '<i>♪ Oh, red\xa0♪</i>'],
#  [4200.208, 4202.75, '<i>♪ Executioner-style\xa0♪</i>'],
#  [4202.833, 4205.0, "<i>♪ And there won't be no trial\xa0♪</i>"],
#  [4205.083,
#   4208.5,
#   "<i>♪ Don't you know\nThat you're better off dead?\xa0♪</i>"],
#  [4208.583, 4211.125, '<i>♪ All I see is red\xa0♪</i>'],
#  [4212.333, 4213.583, '<i>♪ Red\xa0♪</i>'],
#  [4213.916, 4215.375, '<i>♪ Oh, red\xa0♪</i>'],
#  [4217.333, 4219.416, '<i>♪ Now all I see is\xa0♪</i>'],
#  [4238.833, 4239.958, '<i>♪ Red\xa0♪</i>'],
#  [4242.541, 4244.541, '<i>♪ I...♪</i>'],
#  [4245.166, 4249.208, "<i>♪ Oh, you're so done ♪</i>"],
#  [4250.5, 4255.125, '<i>♪ You better sleep\nWith one eye open tonight ♪</i>'],
#  [4255.208, 4257.208, '<i>♪ I see red\xa0♪</i>'],
#  [4258.083, 4259.333, '<i>♪ Red\xa0♪</i>'],
#  [4259.666, 4262.25, '<i>♪ Oh, red\xa0♪</i>'],
#  [4262.833, 4265.958, '<i>♪ Oh, a gun to your head\xa0♪</i>'],
#  [4267.458, 4268.583, '<i>♪ Head\xa0♪</i>'],
#  [4269.291, 4272.375, '<i>♪ To your head\xa0♪</i>'],
#  [4272.458, 4273.458, '<i>♪ Oh\xa0♪</i>'],
#  [4273.541, 4275.75, '<i>♪ Executioner-style\xa0♪</i>'],
#  [4275.833, 4278.625, "<i>♪ And there won't be no trial\xa0♪</i>"],
#  [4278.708,
#   4281.625,
#   "<i>♪ Don't you know\nThat you're better off dead?\xa0♪</i>"],
#  [4281.708, 4284.833, '<i>♪ All I see is red\xa0♪</i>'],
#  [4285.666, 4287.0, '<i>♪ Red ♪</i>'],
#  [4287.083, 4288.958, '<i>♪ Oh, red\xa0♪</i>'],
#  [4290.833, 4292.958, '<i>♪ Now all I see is\xa0♪</i>'],
#  [4293.958, 4294.875, '<i>♪ Red\xa0♪</i>'],
#  [4296.125, 4297.166, '<i>♪ Red\xa0♪</i>'],
#  [4328.875, 4329.791, '<i>Mmm.</i>'],
#  [4329.875, 4331.166, '<i>I want more.</i>'],
#  [4332.416, 4333.958, '<i>We slept only one hour.\xa0</i>'],
#  [4334.75, 4336.041, '<i>Are you tired already?</i>'],
#  [4337.166, 4338.041, '<i>No.</i>'],
#  [4339.166,
#   4342.416,
#   "<i>I just wonder if you aren't too tired\nfor an evening surprise.</i>"],
#  [4344.125, 4346.583, "<i>- I'm afraid of your surprises.</i>"],
#  [4346.666, 4347.708, "<i>You'll like it.</i>"],
#  [4348.916, 4349.916, '<i>What is it?</i>'],
#  [4352.75, 4354.041, "<i>We're going to a ball.</i>"],
#  [4355.708, 4356.666, '<i>A ball?</i>'],
#  [4359.916, 4361.625, '<i>With the nice, long dresses?</i>'],
#  [4362.291, 4363.208, '<i>Uh-huh.</i>'],
#  [4363.875,
#   4365.958,
#   '<i>Are you fucking crazy?\nI have nothing to wear!</i>'],
#  [4366.041, 4367.458, '<i>- Fuck!</i>'],
#  [4423.666, 4424.583, '<i>So...</i>'],
#  [4425.75, 4427.875, '<i>do you mind if I ask you to dance with me?</i>'],
#  [4429.625, 4431.416, "<i>Don Massimo, you're asking?</i>"],
#  [4434.0, 4435.208, '<i>How surprising.</i>'],
#  [4537.625, 4538.541, '<i>Bravo.</i>'],
#  [4540.75, 4541.875, '<i>Bravo.</i>'],
#  [4542.291, 4544.041, '<i>Beautiful dance.</i>'],
#  [4545.583, 4546.666, '<i>Thank you.</i>'],
#  [4547.125, 4549.041, "<i>So, you've found her?</i>"],
#  [4550.375, 4551.333, '<i>Laura.</i>'],
#  [4557.708, 4558.541, '<i>Anna.</i>'],
#  [4559.541, 4561.916, '<i>The first and real love of Massimo.</i>'],
#  [4563.458, 4564.791, '<i>What do you want?</i>'],
#  [4566.041, 4567.833, '<i>I expected better.</i>'],
#  [4569.875, 4570.791, '<i>Enough.</i>'],
#  [4573.833, 4575.0, '<i>Shall I kill her?</i>'],
#  [4575.083, 4577.833, "<i>I'll take\nthe most precious thing you have.</i>"],
#  [4579.083, 4581.25, '<i>Like you did to me.</i>'],
#  [4593.166, 4594.291, '<i>Well?</i>'],
#  [4594.75, 4595.916, "<i>I'm waiting.</i>"],
#  [4597.041, 4597.958, '<i>Anna...</i>'],
#  [4598.458, 4599.5, '<i>is quite recent.</i>'],
#  [4599.958, 4601.0, '<i>How recent?</i>'],
#  [4602.166, 4604.208, '<i>I left her the day you landed in Sicily.</i>'],
#  [4605.25, 4606.541, '<i>I never lied to her.</i>'],
#  [4607.416,
#   4610.25,
#   '<i>Your portraits have been hanging\nin my house for years.</i>'],
#  [4612.083, 4614.416, '<i>Nobody believed that I will ever find you.</i>'],
#  [4615.541, 4617.583, "<i>And... she didn't believe at all.</i>"],
#  [4617.666, 4618.583, '<i>What did she say?</i>'],
#  [4618.666, 4619.666, "<i>It doesn't matter.</i>"],
#  [4620.458, 4621.458, '<i>I want to know.</i>'],
#  [4624.958, 4626.0, '<i>She said that...</i>'],
#  [4626.416, 4627.375, '<i>she will kill you.</i>'],
#  [4630.083, 4631.0, '<i>Laura...</i>'],
#  [4633.25, 4635.125, '<i>I will never let anyone hurt you.</i>'],
#  [4635.458, 4636.791, "<i>I'll take care of her.</i>"],
#  [4639.0, 4640.083, '<i>I want to leave.</i>'],
#  [4642.333, 4643.166, '<i>Now.</i>'],
#  [4706.0, 4709.041, "<i>♪ I'm gonna light like fire\xa0♪</i>"],
#  [4709.416, 4711.791, "<i>♪ I'm coming down like rain\xa0♪</i>"],
#  [4712.458, 4715.291, "<i>♪ I'm gonna break down barriers\xa0♪</i>"],
#  [4715.708, 4718.166, "<i>♪ I'm gonna play through the pain\xa0♪</i>"],
#  [4718.833, 4721.958, "<i>♪ I'm gonna rise like a phoenix\xa0♪</i>"],
#  [4722.041, 4724.666, "<i>♪ I'm gonna fight through the flame\xa0♪</i>"],
#  [4726.458, 4728.875, "<i>♪ Devil won't drag me down\xa0♪</i>"],
#  [4729.25, 4730.916, "<i>♪ 'Cause I'm done ♪</i>"],
#  [4731.333, 4734.083, "<i>♪ I'm all done playing games\xa0♪</i>"],
#  [4734.833, 4737.708, "<i>♪ I'm gonna light like fire\xa0♪</i>"],
#  [4738.083, 4740.5, "<i>♪ I'm coming down like rain\xa0♪</i>"],
#  [4741.375, 4744.166, "<i>♪ I'm gonna break down barriers\xa0♪</i>"],
#  [4744.583, 4746.916, "<i>♪ I'm gonna play through the pain\xa0♪</i>"],
#  [4747.666, 4750.583, "<i>♪ I'm gonna rise like a phoenix\xa0♪</i>"],
#  [4750.875, 4753.25, "<i>♪ I'm gonna fight through the flame\xa0♪</i>"],
#  [4760.416, 4763.416, "<i>♪ I'm gonna rise like a phoenix\xa0♪</i>"],
#  [4763.666, 4766.083, "<i>♪ I'm gonna fight through the flame\xa0♪</i>"],
#  [4768.125, 4770.5, "<i>♪ Devil won't drag me down\xa0♪</i>"],
#  [4770.875, 4772.458, "<i>♪ 'Cause I'm done ♪</i>"],
#  [4773.0, 4776.041, "<i>♪ I'm all done playing games\xa0♪</i>"],
#  [4809.625,
#   4812.041,
#   '<i>Domenico will take you\nto the airport tomorrow.</i>'],
#  [4814.125, 4815.583, '<i>Your flight is at 8:00.</i>'],
#  [4816.875, 4817.791, '<i>What?</i>'],
#  [4818.708, 4819.625, '<i>What flight?</i>'],
#  [4821.208, 4822.166, '<i>To Poland.</i>'],
#  [4822.958, 4824.375, '<i>What are you talking about?</i>'],
#  [4827.541, 4829.708, '<i>You said\nthat you want to visit your family.</i>'],
#  [4831.583,
#   4833.666,
#   "<i>- Yes, but...\n- There's an apartment waiting for you</i>"],
#  [4833.75, 4834.583, '<i>in Warsaw.</i>'],
#  [4836.291, 4837.666, "<i>I'll join you there soon.</i>"],
#  [4857.208, 4858.291, '<i>I love you.</i>'],
#  [4869.791, 4871.291, '<i>I mean, come on.</i>'],
#  [4872.625, 4874.083, '<i>Forget about Anna.</i>'],
#  [4876.25, 4877.5, "<i>She's the past.</i>"],
#  [4878.875, 4879.75, '<i>Is she?</i>'],
#  [4879.833, 4880.708, '<i>Yes.</i>'],
#  [4881.75, 4883.083, '<i>And you, my darling,</i>'],
#  [4884.541, 4886.0, '<i>you are the fucking future.</i>'],
#  [4887.916, 4889.208, '<i>Where exactly is she?</i>'],
#  [4892.208, 4893.958, '<i>Well... Sorry.</i>'],
#  [4894.625, 4895.666, '<i>Hello?</i>'],
#  [4904.833, 4905.75, '<i>Stop.</i>'],
#  [4906.333, 4907.666, "<i>What's going on?</i>"],
#  [4909.0, 4910.375, '<i>Domenico, what happened?</i>'],
#  [4911.541, 4912.916, '<i>Wait in Warsaw.</i>'],
#  [4913.333, 4914.291, '<i>What?</i>'],
#  [4915.458, 4917.375, '<i>Wait in Warsaw.</i>'],
#  [4926.666, 4927.708, '<i>Domenico?</i>'],
#  [4930.708, 4934.5, '<i>♪ Braced cords as you turn\xa0♪</i>'],
#  [4937.541, 4941.041, '<i>♪ To this course you set upon\xa0♪</i>'],
#  [4944.375, 4948.0, '<i>♪ The sea coming all alive\xa0♪</i>'],
#  [4951.208, 4955.125, '<i>♪ And every ray when it arrives\xa0♪</i>'],
#  [4957.125, 4960.958, "<i>♪ 'Cause I know you won't be\xa0♪</i>"],
#  [4963.75, 4965.333, '<i>♪ Coming back\xa0♪</i>'],
#  [4967.375, 4969.25, '<i>♪ Coming back\xa0♪</i>'],
#  [4983.333, 4985.083, '<i>Laura, no fucking way!</i>'],
#  [4985.541, 4987.375, "<i>I wasn't talking to you.\nI'll call you back.</i>"],
#  [4989.083, 4990.708, '<i>I am going to kill you!</i>'],
#  [4992.125, 4993.583, '<i>I thought you were kidnapped!</i>'],
#  [4996.125, 4998.125, '<i>Just tell me one thing, okay?</i>'],
#  [4998.208, 5000.291, '<i>What happened in fucking Sicily?</i>'],
#  [5000.375,
#   5003.833,
#   '<i>- Martin. I had enough of him.\n- Did he piss you off?</i>'],
#  [5005.416, 5006.416, '<i>I fell in love.</i>'],
#  [5009.958, 5010.791, '<i>What the fuck?</i>'],
#  [5010.875,
#   5014.666,
#   "<i>Jesus, I know it sounds ridiculous.\nI didn't want it, but things happened.</i>"],
#  [5017.083, 5018.291, '<i>Fucking great.</i>'],
#  [5021.041,
#   5024.416,
#   "<i>Don't make me force it out of you.\nTell me, who is it?</i>"],
#  [5024.666, 5026.333, '<i>He is... special.</i>'],
#  [5026.458,
#   5028.958,
#   "<i>What do you mean? He's got special needs?\nIs he sick?</i>"],
#  [5029.041, 5030.333, '<i>I know, he has flat feet.</i>'],
#  [5030.5, 5031.875, '<i>Olga, shut up!</i>'],
#  [5031.958, 5033.125, '<i>Tell me!</i>'],
#  [5035.25,
#   5038.375,
#   '<i>Imagine a strong alpha male,\nwho always knows what he wants.</i>'],
#  [5038.791, 5041.541, '<i>He is your caretaker and your defender.</i>'],
#  [5042.5,
#   5045.0,
#   '<i>When you are with him,\nyou feel like a little girl.</i>'],
#  [5045.75, 5048.708, '<i>He makes\nall your sexual fantasies come true.</i>'],
#  [5049.791, 5050.833, '<i>Um...</i>'],
#  [5050.916,
#   5053.458,
#   "<i>What's more,\nhe is one meter, 90 centimeters tall,</i>"],
#  [5053.541,
#   5056.666,
#   '<i>has absolutely no body fat,\nand has been molded by God himself.</i>'],
#  [5057.833, 5059.583, '<i>Did God mold his dick, too?</i>'],
#  [5068.75, 5069.75, '<i>The devil did.</i>'],
#  [5077.708, 5079.458, '<i>Fuck me.</i>'],
#  [5081.416, 5082.375, '<i>So, what about him?</i>'],
#  [5084.833, 5085.708, '<i>Mmm.</i>'],
#  [5085.791, 5087.791, '<i>- We have to think this through.\n- Mm-hmm.</i>'],
#  [5090.083,
#   5092.875,
#   '<i>He comes from a rich,\ntraditional Sicilian family.</i>'],
#  [5094.0, 5095.916, "<i>They don't take foreigners for wives.</i>"],
#  [5102.583, 5104.875, '<i>Right, now spare me the bullshit.</i>'],
#  [5105.875, 5107.291, '<i>Tell me the truth.</i>'],
#  [5123.0, 5125.541, "<i>Olga, I'm fucked up.</i>"],
#  [5125.916,
#   5128.916,
#   '<i>I was kidnapped by a gangster,\nand then I fell in love with him.</i>'],
#  [5129.0,
#   5132.875,
#   '<i>And the worst thing\nis that they keep me in the dark.</i>'],
#  [5132.958, 5135.416, '<i>They treat me like some kind of doll.</i>'],
#  [5135.5,
#   5138.0,
#   "<i>They sent me to Poland,\nand I still don't know a single thing.</i>"],
#  [5138.083,
#   5141.0,
#   "<i>That's why you need to fucking back out.\nDo you understand?</i>"],
#  [5141.083,
#   5144.25,
#   '<i>Fuck all the Massimos, Martins,\nand all the other mozzarellas.</i>'],
#  [5147.333, 5148.541, "<i>It's time for a change.</i>"],
#  [5150.875, 5151.958, '<i>A change of undies.</i>'],
#  [5152.291, 5153.666, '<i>- We are going out.\n- What?</i>'],
#  [5158.833, 5160.333, '<i>What are you doing?</i>'],
#  [5160.75, 5162.875, "<i>I'm conditioning my neighbors.</i>"],
#  [5167.333, 5169.041, '<i>Hi, bitches!</i>'],
#  [5169.125,
#   5173.833,
#   "<i>Darius, just fucking look at you!\nPlease, don't leave, though.</i>"],
#  [5174.083,
#   5177.958,
#   "<i>Can you tell me why you woke me up\nin the middle of the night? It's 1:00 p.m.</i>"],
#  [5178.208, 5180.041, '<i>Fucking rejuvenation time!</i>'],
#  [5180.25, 5181.375, '<i>Just look at her!</i>'],
#  [5184.541, 5185.916, '<i>- Yeah, bad.\n- Mmm.</i>'],
#  [5187.666, 5189.25, '<i>How about some glasses?</i>'],
#  [5189.666, 5192.041, '<i>Greg, I want some volume here.</i>'],
#  [5192.125, 5193.208, '<i>Hello?</i>'],
#  [5199.958, 5202.333, '<i>What? Did you suddenly have a stroke?</i>'],
#  [5210.5,
#   5213.416,
#   '<i>I was offered the position\nof general manager at Preston.</i>'],
#  [5215.791, 5217.958, '<i>You will be fucking General Preston!</i>'],
#  [5218.041, 5219.25, '<i>Fucking shit!</i>'],
#  [5222.541,
#   5227.583,
#   '<i>Great. Mozzarella turned her brain\ninto pesto.</i>'],
#  [5229.0, 5230.958, '<i>Now, that is some serious volume.</i>'],
#  [5234.375,
#   5236.75,
#   "<i>You're right. I'm not going\nto just lie down and smell nice.</i>"],
#  [5241.833, 5243.333, "<i>I'd like to lie down and smell nice...</i>"],
#  [5251.0, 5251.916, '<i>Hey.</i>'],
#  [5253.583, 5255.041, '<i>Hey! Stand in line!</i>'],
#  [5255.125, 5256.625, '<i>There is a line to your ass.</i>'],
#  [5257.291, 5259.791, "<i>♪ Don't call me up\nI'm going out tonight\xa0♪</i>"],
#  [5259.875, 5261.75, "<i>♪ Feeling good now you're outta my life\xa0♪</i>"],
#  [5261.833, 5263.583, "<i>♪ Don't wanna talk about us\xa0♪</i>"],
#  [5263.666,
#   5266.208,
#   "<i>♪ Gotta leave it behind\nOne drink and you're outta my mind\xa0♪</i>"],
#  [5266.291, 5268.0, '<i>♪ Now, now, take it up\xa0♪</i>'],
#  [5268.083,
#   5270.958,
#   "<i>♪ Baby, I'm on a high\nYou're alone, going out of your mind\xa0\xa0♪</i>"],
#  [5271.041, 5272.791, '<i>- Did you hurt yourself?</i>'],
#  [5274.0, 5275.708, "<i>♪ And I don't wanna talk\xa0♪</i>"],
#  [5275.791, 5277.291, '<i>When falling down from heaven?</i>'],
#  [5277.875,
#   5280.083,
#   "<i>- Bye.</i>\n- ♪ 'Cause I'm here looking fine, babe\xa0♪</i>"],
#  [5280.166, 5282.5, '<i>♪ And I got eyes looking my way\xa0♪</i>'],
#  [5282.583, 5284.375, "<i>♪ And everybody's on my vibe, babe\xa0♪</i>"],
#  [5284.458, 5287.458, "<i>♪ Now, now, now, now\nDon't call me up... ♪</i>"],
#  [5292.208, 5294.5, "<i>It's for you. From that gentleman.</i>"],
#  [5298.375, 5299.583, '<i>- No.\n- Mm-hmm.</i>'],
#  [5299.666, 5300.5, '<i>Uh-uh.</i>'],
#  [5302.125, 5303.375, '<i>- Mm-hmm.\n- Uh-uh.</i>'],
#  [5303.458, 5305.166, '<i>- Mm-hmm.\n- No.</i>'],
#  [5326.5, 5327.458, '<i>Laura.</i>'],
#  [5330.916, 5332.333, '<i>Hi.</i>'],
#  [5334.541, 5336.0, '<i>Where were you all this time?</i>'],
#  [5338.125, 5339.208, '<i>Can we talk?</i>'],
#  [5339.291, 5340.833, '<i>I have nothing to say to you.</i>'],
#  [5340.916,
#   5344.791,
#   "<i>Laura, please. At least let me explain,\nand then I'll leave.</i>"],
#  [5345.125,
#   5347.625,
#   "<i>Explain how your dick ended up\nin a different girl's ass?</i>"],
#  [5347.958, 5349.958, '<i>The moment you ran off from that pool...</i>'],
#  [5350.25,
#   5353.583,
#   "<i>I thought this through. You were right.\nI ran after you, but you weren't there.</i>"],
#  [5354.125,
#   5356.75,
#   '<i>I started looking for you.\nIt got dark, so I went back to the hotel.</i>'],
#  [5356.833,
#   5360.541,
#   '<i>I found your letter, read it...\nand lost my mind.</i>'],
#  [5360.625,
#   5362.708,
#   '<i>I decided I needed to get fucked up.\nI called Michał...</i>'],
#  [5363.041, 5364.791, '<i>And please, believe me...</i>'],
#  [5365.208,
#   5367.666,
#   '<i>that fucking first drink\nwas the last thing that I remember</i>'],
#  [5367.75, 5368.958, '<i>from that evening.</i>'],
#  [5369.041, 5370.208, '<i>When I woke up...</i>'],
#  [5374.041,
#   5376.166,
#   "<i>It doesn't change a thing\nif you remember or not.</i>"],
#  [5376.25, 5377.75, '<i>You slept with another girl.</i>'],
#  [5378.708, 5380.041, '<i>But...</i>'],
#  [5380.333, 5383.791, '<i>There are no "buts," Martin!</i>'],
#  [5383.875,
#   5389.791,
#   '<i>We belong to two different worlds.\nThere is no room for a woman in your life.</i>'],
#  [5389.875,
#   5392.125,
#   '<i>And I am not going to be your toy.\nDo you understand?</i>'],
#  [5392.208, 5393.458, "<i>It's all true, Laura.</i>"],
#  [5394.291, 5395.958, '<i>But that is in the past.</i>'],
#  [5397.041, 5399.041, '<i>I came to realize that...</i>'],
#  [5399.875, 5400.916, '<i>I really love you.</i>'],
#  [5401.0, 5402.583, "<i>I think I'm gonna puke.</i>"],
#  [5403.0, 5404.208, "<i>I'm going home.</i>"],
#  [5439.166, 5441.041, '<i>- Just five minutes.\n- Goodbye!</i>'],
#  [5441.125, 5442.25, '<i>Laura, I really miss you.</i>'],
#  ...]
