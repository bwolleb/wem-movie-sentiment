# %%
import cv2

# %%
# Load the image from disk.
image = cv2.imread('000c67c4f31211edb451b8aeed79c0cc')

# %%
import matplotlib.pyplot as plt
plt.imshow(image)
plt.show()

# %%
from PIL import Image

# Load the image from disk.
image = Image.open('000c67c4f31211edb451b8aeed79c0cc')
