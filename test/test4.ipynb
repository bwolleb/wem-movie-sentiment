# %%
from transformers import pipeline
classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")

# %%
sequence_to_classify = "one day I will see the world"
candidate_labels = ['travel', 'cooking', 'dancing']
classifier(sequence_to_classify, candidate_labels)
# Out:
# {'sequence': 'one day I will see the world',
#  'labels': ['travel', 'dancing', 'cooking'],
#  'scores': [0.9938651919364929, 0.003273811424151063, 0.0028610352892428637]}

# %%
f = open("tags")
tags = f.read().split("\n")
f.close()

# %%
tags.pop(tags.index(""))
# Out:
# ''

# %%
classifier(sequence_to_classify, tags)
# Out:
# {'sequence': 'one day I will see the world',
#  'labels': ['travel',
#   'future',
#   'sequel',
#   'journey',
#   'coming of age',
#   'futuristic',
#   'fragment',
#   'coming out',
#   'alien',
#   'multiple time frames',
#   'partially lost film',
#   'ambiguous ending',
#   'voyeur',
#   'dream',
#   'title spoken by character',
#   'multiple perspectives',
#   'secret',
#   'mystery',
#   'tour',
#   'blind',
#   'multiple endings',
#   'surprise ending',
#   'stranger',
#   'female protagonist',
#   'idealism',
#   'spectacle',
#   'avant garde',
#   'experimental',
#   'legend',
#   'making of',
#   'travelogue',
#   'behind the scenes',
#   'on the run',
#   'subjective camera',
#   'new zealand',
#   'short',
#   'show within a show',
#   'multiple storyline',
#   'artist',
#   'isolation',
#   'hungary',
#   'blindness',
#   'famous line',
#   'history',
#   'surreal',
#   'faith',
#   'lost film',
#   'slice of life',
#   'author',
# ...

# %%
from transformers import pipeline
classifier = pipeline("zero-shot-classification",  model="BaptisteDoyen/camembert-base-xnli")

# %%
sequence_to_classify = "Let's go to the spaceship"
classifier(sequence_to_classify, tags)
# Out:
# {'sequence': "Let's go to the spaceship",
#  'labels': ['space travel',
#   'space',
#   'ship',
#   'transformation',
#   'environment',
#   'travel',
#   'climate change',
#   'shipwreck',
#   'composer',
#   'relationship',
#   'relationship problems',
#   'coming out',
#   'time travel',
#   'break up',
#   'cave',
#   'travelogue',
#   'behind the scenes',
#   'exploitation',
#   'post apocalyptic future',
#   'god',
#   'stop motion',
#   'witch',
#   'parenthood',
#   'circus',
#   'sibling relationship',
#   'tour',
#   'adoption',
#   'subway',
#   'railroad',
#   'vacation',
#   'claymation',
#   'loss',
#   'countryside',
#   'future',
#   'theater play',
#   'on the run',
#   'hell',
#   'river',
#   'making of',
#   'reunion',
#   'opening action scene',
#   'guilt',
#   'island',
#   'avant garde',
#   'government',
#   'lawyer',
#   'greed',
#   'modeling',
#   'extramarital affair',
#   'rescue',
#   'architecture',
#   'home invasion',
#   'corpse',
# ...
